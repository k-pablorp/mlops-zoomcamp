# %%
import pandas as pd
import mlflow

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso

from sklearn.metrics import root_mean_squared_error

# %%
mlflow.set_tracking_uri('sqlite:///mlflow.db')
mlflow.set_experiment('nyc-taxi-experiment')
# Out:
# 2025/11/07 11:04:12 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/11/07 11:04:12 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# <Experiment: artifact_location='/workspaces/mlops-zoomcamp/02-experiment-tracking/mlruns/2', creation_time=1762437757019, experiment_id='2', last_update_time=1762437757019, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %% [markdown]
# ## Importamos los datos

# %%
def prepare_dataframe(url):
    df = pd.read_parquet(url)
    
    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)
    
    df = df[(df.duration >= 1) & (df.duration <= 60)]
    
    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = prepare_dataframe('https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-01.parquet')
df_val = prepare_dataframe('https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-02.parquet')

# %%
df_train
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2021-01-01 00:15:56   2021-01-01 00:19:52                  N
# 1             2  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2             2  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3             2  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 7             2  2021-01-01 00:26:31   2021-01-01 00:28:50                  N
# ...         ...                  ...                   ...                ...
# 76513         2  2021-01-31 21:38:00   2021-01-31 22:16:00               None
# 76514         2  2021-01-31 22:43:00   2021-01-31 23:21:00               None
# 76515         2  2021-01-31 22:16:00   2021-01-31 22:27:00               None
# 76516         2  2021-01-31 23:10:00   2021-01-31 23:37:00               None
# 76517         2  2021-01-31 23:25:00   2021-01-31 23:35:00               None
#
#        RatecodeID PULocationID DOLocationID  passenger_count  trip_distance  \
# 0             1.0           43          151              1.0           1.01
# 1             1.0          166          239              1.0           2.53
# 2             1.0           41           42              1.0           1.12
# 3             1.0          168           75              1.0           1.99
# 7             1.0           75           75              6.0           0.45
# ...           ...          ...          ...              ...            ...
# 76513         NaN           81           90              NaN          17.63
# 76514         NaN           35          213              NaN          18.36
# 76515         NaN           74           69              NaN           2.50
# 76516         NaN          168          215              NaN          14.48
# 76517         NaN          119          244              NaN           1.81
#
#        fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0             5.50  ...      0.5        0.00          0.00       None
# 1            10.00  ...      0.5        2.81          0.00       None
# 2             6.00  ...      0.5        1.00          0.00       None
# 3             8.00  ...      0.5        0.00          0.00       None
# 7             3.50  ...      0.5        0.96          0.00       None
# ...            ...  ...      ...         ...           ...        ...
# 76513        56.23  ...      0.0        0.00          6.12       None
# 76514        46.66  ...      0.0       12.20          6.12       None
# 76515        18.95  ...      0.0        0.00          0.00       None
# 76516        48.87  ...      0.0        0.00          6.12       None
# 76517        15.45  ...      0.0        0.00          0.00       None
#
#       improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                       0.3          6.80           2.0        1.0
# 1                       0.3         16.86           1.0        1.0
# 2                       0.3          8.30           1.0        1.0
# 3                       0.3          9.30           2.0        1.0
# 7                       0.3          5.76           1.0        1.0
# ...                     ...           ...           ...        ...
# 76513                   0.3         65.40           NaN        NaN
# 76514                   0.3         65.28           NaN        NaN
# 76515                   0.3         22.00           NaN        NaN
# 76516                   0.3         58.04           NaN        NaN
# 76517                   0.3         18.50           NaN        NaN
#
#        congestion_surcharge   duration
# 0                      0.00   3.933333
# 1                      2.75   8.750000
# 2                      0.00   5.966667
# 3                      0.00   7.083333
# 7                      0.00   2.316667
# ...                     ...        ...
# 76513                   NaN  38.000000
# 76514                   NaN  38.000000
# 76515                   NaN  11.000000
# 76516                   NaN  27.000000
# 76517                   NaN  10.000000
#
# [73908 rows x 21 columns]

# %%
df_val
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2021-02-01 00:34:03   2021-02-01 00:51:58                  N
# 1             2  2021-02-01 00:04:00   2021-02-01 00:10:30                  N
# 2             2  2021-02-01 00:18:51   2021-02-01 00:34:06                  N
# 3             2  2021-02-01 00:53:27   2021-02-01 01:11:41                  N
# 4             2  2021-02-01 00:57:46   2021-02-01 01:06:44                  N
# ...         ...                  ...                   ...                ...
# 64567         2  2021-02-28 22:19:00   2021-02-28 22:29:00               None
# 64568         2  2021-02-28 23:18:00   2021-02-28 23:27:00               None
# 64569         2  2021-02-28 23:44:00   2021-02-28 23:58:00               None
# 64570         2  2021-02-28 23:07:00   2021-02-28 23:14:00               None
# 64571         2  2021-02-28 23:43:00   2021-02-28 23:50:00               None
#
#        RatecodeID PULocationID DOLocationID  passenger_count  trip_distance  \
# 0             1.0          130          205              5.0           3.66
# 1             1.0          152          244              1.0           1.10
# 2             1.0          152           48              1.0           4.93
# 3             1.0          152          241              1.0           6.70
# 4             1.0           75           42              1.0           1.89
# ...           ...          ...          ...              ...            ...
# 64567         NaN          129            7              NaN           2.63
# 64568         NaN          116          166              NaN           1.87
# 64569         NaN           74          151              NaN           2.40
# 64570         NaN           42           42              NaN           1.11
# 64571         NaN           42           41              NaN           1.40
#
#        fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0            14.00  ...      0.5       10.00           0.0       None
# 1             6.50  ...      0.5        0.00           0.0       None
# 2            16.50  ...      0.5        0.00           0.0       None
# 3            21.00  ...      0.5        0.00           0.0       None
# 4             8.50  ...      0.5        2.45           0.0       None
# ...            ...  ...      ...         ...           ...        ...
# 64567        10.04  ...      0.0        0.00           0.0       None
# 64568         8.33  ...      0.0        1.89           0.0       None
# 64569        12.61  ...      0.0        0.00           0.0       None
# 64570        11.95  ...      0.0        0.00           0.0       None
# 64571         8.21  ...      0.0        0.00           0.0       None
#
#       improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                       0.3         25.30           1.0        1.0
# 1                       0.3          7.80           2.0        1.0
# 2                       0.3         20.55           2.0        1.0
# 3                       0.3         22.30           2.0        1.0
# 4                       0.3         12.25           1.0        1.0
# ...                     ...           ...           ...        ...
# 64567                   0.3         10.34           NaN        NaN
# 64568                   0.3         10.52           NaN        NaN
# 64569                   0.3         12.91           NaN        NaN
# 64570                   0.3         15.00           NaN        NaN
# 64571                   0.3          8.51           NaN        NaN
#
#        congestion_surcharge   duration
# 0                      0.00  17.916667
# 1                      0.00   6.500000
# 2                      2.75  15.250000
# 3                      0.00  18.233333
# 4                      0.00   8.966667
# ...                     ...        ...
# 64567                   NaN  10.000000
# 64568                   NaN   9.000000
# 64569                   NaN  14.000000
# 64570                   NaN   7.000000
# 64571                   NaN   7.000000
#
# [61921 rows x 21 columns]

# %% [markdown]
# ## Feature selection

# %%
categorical = ['PULocationID', 'DOLocationID']
numerical = ['trip_distance']

# %% [markdown]
# Necesitamos convertir las variables categóricas a binarias (One Hot Encoding). Para ello necesitamos que sean strings

# %%
df_train[categorical] = df_train[categorical].astype(str)

# %%
train_dicts = df_train[categorical + numerical].to_dict(orient='records')

# %%
dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)

# %%
target = 'duration'
y_train = df_train[target].values

# %% [markdown]
# ## Training

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Validate

# %%
val_dicts = df_val[categorical + numerical].to_dict(orient='records')

# %%
y_val = df_val[target].values

# %%
X_val = dv.transform(val_dicts)

# %%
y_pred = lr.predict(X_val)

root_mean_squared_error(y_val, y_pred)
# Out:
# 10.499110710357629

# %%
sns.distplot(y_pred, label = 'prediction')
sns.distplot(y_val, label = 'actual')

plt.legend()
# Out:
# /tmp/ipykernel_49665/1882562538.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_pred, label = 'prediction')
# /tmp/ipykernel_49665/1882562538.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_val, label = 'actual')

# %%
# Vamos a intentar mejorar la regresión utilizando una variable categórica conjunta en lugar de 2 separadas
df_train['PU_DU'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DU'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DU']

# %%
train_dicts = df_train[categorical + numerical].to_dict(orient='records')

X_train = dv.fit_transform(train_dicts)

lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
val_dicts = df_val[categorical + numerical].to_dict(orient='records')

# %%
X_val = dv.transform(val_dicts)

# %%
y_pred = lr.predict(X_val)

root_mean_squared_error(y_val, y_pred)
# Out:
# 7.758715208009878

# %%
with mlflow.start_run():
    mlflow.set_tag('developer', 'pablo')
    mlflow.log_param('train-data-path', 'https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-01.parquet')
    mlflow.log_param('validate-data-path', 'https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-02.parquet')
    
    alpha = 0.01
    mlflow.log_param('alpha', alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)
    
    y_pred = lr.predict(X_val)

    rmse = root_mean_squared_error(y_val, y_pred)

    mlflow.log_metric('rmse', rmse)

# %% [markdown]
# ## Probando el modelo xgboost

# %%
import xgboost as xgb
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope
# Out:
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/atpe.py:19: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = root_mean_squared_error(y_val, y_pred)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
#   0%|                                                                                                                                    | 0/50 [00:00<?, ?trial/s, best loss=?]
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [11:27:15] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:11.80475
# [1]	validation-rmse:11.42365
# [2]	validation-rmse:11.06820
# [3]	validation-rmse:10.73716
# [4]	validation-rmse:10.42911
# [5]	validation-rmse:10.14283
# [6]	validation-rmse:9.87699
# [7]	validation-rmse:9.63042
# [8]	validation-rmse:9.40189
# [9]	validation-rmse:9.19030
# [10]	validation-rmse:8.99469
# [11]	validation-rmse:8.81399
# [12]	validation-rmse:8.64704
# [13]	validation-rmse:8.49322
# [14]	validation-rmse:8.35133
# [15]	validation-rmse:8.22060
# [16]	validation-rmse:8.10034
# [17]	validation-rmse:7.98971
# [18]	validation-rmse:7.88779
# [19]	validation-rmse:7.79414
# [20]	validation-rmse:7.70778
# [21]	validation-rmse:7.62853
# [22]	validation-rmse:7.55616
# [23]	validation-rmse:7.48926
# [24]	validation-rmse:7.42790
# [25]	validation-rmse:7.37161
# [26]	validation-rmse:7.32006
# [27]	validation-rmse:7.27301
# [28]	validation-rmse:7.22971
# [29]	validation-rmse:7.18997
# [30]	validation-rmse:7.15349
# [31]	validation-rmse:7.12003
# [32]	validation-rmse:7.08935
# [33]	validation-rmse:7.06112
# [34]	validation-rmse:7.03536
# [35]	validation-rmse:7.01142
# [36]	validation-rmse:6.98950
# [37]	validation-rmse:6.96867
# [38]	validation-rmse:6.94922
# [39]	validation-rmse:6.93130
# [40]	validation-rmse:6.91498
# [41]	validation-rmse:6.89994
# [42]	validation-rmse:6.88568
# [43]	validation-rmse:6.87252
# [44]	validation-rmse:6.86062
# [45]	validation-rmse:6.84930
# [46]	validation-rmse:6.83883
# [47]	validation-rmse:6.82884
# [48]	validation-rmse:6.81952
# [49]	validation-rmse:6.81087
# [50]	validation-rmse:6.80319
# [51]	validation-rmse:6.79567
# [52]	validation-rmse:6.78905
# [53]	validation-rmse:6.78258
# [54]	validation-rmse:6.77672
# [55]	validation-rmse:6.77102
# [56]	validation-rmse:6.76597
# [57]	validation-rmse:6.76125
# [58]	validation-rmse:6.75659
# [59]	validation-rmse:6.75226
# [60]	validation-rmse:6.74827
# [61]	validation-rmse:6.74460
# [62]	validation-rmse:6.74113
# [63]	validation-rmse:6.73797
# [64]	validation-rmse:6.73473
# [65]	validation-rmse:6.73192
# [66]	validation-rmse:6.72922
# [67]	validation-rmse:6.72658
# [68]	validation-rmse:6.72426
# [69]	validation-rmse:6.72201
# [70]	validation-rmse:6.71967
# [71]	validation-rmse:6.71728
# [72]	validation-rmse:6.71479
# [73]	validation-rmse:6.71284
# [74]	validation-rmse:6.71026
# [75]	validation-rmse:6.70856
# [76]	validation-rmse:6.70681
# [77]	validation-rmse:6.70472
# [78]	validation-rmse:6.70285
# [79]	validation-rmse:6.70102
# [80]	validation-rmse:6.69966
# [81]	validation-rmse:6.69793
# [82]	validation-rmse:6.69628
# [83]	validation-rmse:6.69469
# [84]	validation-rmse:6.69326
# [85]	validation-rmse:6.69190
# [86]	validation-rmse:6.69059
# [87]	validation-rmse:6.68942
# [88]	validation-rmse:6.68845
# [89]	validation-rmse:6.68737
# [90]	validation-rmse:6.68654
# [91]	validation-rmse:6.68556
# [92]	validation-rmse:6.68461
# [93]	validation-rmse:6.68374
# [94]	validation-rmse:6.68290
# [95]	validation-rmse:6.68221
# [96]	validation-rmse:6.68160
# [97]	validation-rmse:6.68096
# [98]	validation-rmse:6.68038
# [99]	validation-rmse:6.67992
# [100]	validation-rmse:6.67924
# [101]	validation-rmse:6.67876
# [102]	validation-rmse:6.67827
# [103]	validation-rmse:6.67760
# [104]	validation-rmse:6.67713
# [105]	validation-rmse:6.67664
# [106]	validation-rmse:6.67630
# [107]	validation-rmse:6.67583
# [108]	validation-rmse:6.67535
# [109]	validation-rmse:6.67490
# [110]	validation-rmse:6.67441
# [111]	validation-rmse:6.67409
# [112]	validation-rmse:6.67370
# [113]	validation-rmse:6.67326
# [114]	validation-rmse:6.67304
# [115]	validation-rmse:6.67278
# [116]	validation-rmse:6.67253
# [117]	validation-rmse:6.67215
# [118]	validation-rmse:6.67198
# [119]	validation-rmse:6.67174
# [120]	validation-rmse:6.67157
# [121]	validation-rmse:6.67118
# [122]	validation-rmse:6.67105
# [123]	validation-rmse:6.67075
# [124]	validation-rmse:6.67053
# [125]	validation-rmse:6.67032
# [126]	validation-rmse:6.67010
# [127]	validation-rmse:6.66980
# [128]	validation-rmse:6.66965
# [129]	validation-rmse:6.66939
# [130]	validation-rmse:6.66920
# [131]	validation-rmse:6.66912
# [132]	validation-rmse:6.66891
# [133]	validation-rmse:6.66876
# [134]	validation-rmse:6.66838
# [135]	validation-rmse:6.66825
# [136]	validation-rmse:6.66792
# [137]	validation-rmse:6.66783
# [138]	validation-rmse:6.66770
# [139]	validation-rmse:6.66741
# [140]	validation-rmse:6.66730
# [141]	validation-rmse:6.66711
# [142]	validation-rmse:6.66703
# [143]	validation-rmse:6.66693
# [144]	validation-rmse:6.66683
# [145]	validation-rmse:6.66667
# [146]	validation-rmse:6.66659
# [147]	validation-rmse:6.66633
# [148]	validation-rmse:6.66614
# [149]	validation-rmse:6.66607
# [150]	validation-rmse:6.66597
# [151]	validation-rmse:6.66588
# [152]	validation-rmse:6.66565
# [153]	validation-rmse:6.66543
# [154]	validation-rmse:6.66537
# [155]	validation-rmse:6.66514
# [156]	validation-rmse:6.66506
# [157]	validation-rmse:6.66489
# [158]	validation-rmse:6.66478
# [159]	validation-rmse:6.66472
# [160]	validation-rmse:6.66464
# [161]	validation-rmse:6.66445
# [162]	validation-rmse:6.66438
# [163]	validation-rmse:6.66431
# [164]	validation-rmse:6.66424
# [165]	validation-rmse:6.66412
# [166]	validation-rmse:6.66398
# [167]	validation-rmse:6.66394
# [168]	validation-rmse:6.66388
# [169]	validation-rmse:6.66369
# [170]	validation-rmse:6.66364
# [171]	validation-rmse:6.66344
# [172]	validation-rmse:6.66333
# [173]	validation-rmse:6.66330
# [174]	validation-rmse:6.66322
# [175]	validation-rmse:6.66308
# [176]	validation-rmse:6.66304
# [177]	validation-rmse:6.66289
# [178]	validation-rmse:6.66283
# [179]	validation-rmse:6.66271
# [180]	validation-rmse:6.66263
# [181]	validation-rmse:6.66249
# [182]	validation-rmse:6.66248
# [183]	validation-rmse:6.66238
# [184]	validation-rmse:6.66233
# [185]	validation-rmse:6.66228
# [186]	validation-rmse:6.66213
# [187]	validation-rmse:6.66209
# [188]	validation-rmse:6.66198
# [189]	validation-rmse:6.66193
# [190]	validation-rmse:6.66185
# [191]	validation-rmse:6.66179
# [192]	validation-rmse:6.66176
# [193]	validation-rmse:6.66165
# [194]	validation-rmse:6.66157
# [195]	validation-rmse:6.66152
# [196]	validation-rmse:6.66148
# [197]	validation-rmse:6.66132
# [198]	validation-rmse:6.66115
# [199]	validation-rmse:6.66098
# [200]	validation-rmse:6.66089
# [201]	validation-rmse:6.66076
# [202]	validation-rmse:6.66068
# [203]	validation-rmse:6.66053
# [204]	validation-rmse:6.66040
# [205]	validation-rmse:6.66028
# [206]	validation-rmse:6.66018
# [207]	validation-rmse:6.66014
# [208]	validation-rmse:6.66006
# [209]	validation-rmse:6.65995
# [210]	validation-rmse:6.65989
# [211]	validation-rmse:6.65974
# [212]	validation-rmse:6.65963
# [213]	validation-rmse:6.65953
# [214]	validation-rmse:6.65945
# [215]	validation-rmse:6.65943
# [216]	validation-rmse:6.65937
# [217]	validation-rmse:6.65931
# [218]	validation-rmse:6.65924
# [219]	validation-rmse:6.65916
# [220]	validation-rmse:6.65906
# [221]	validation-rmse:6.65901
# [222]	validation-rmse:6.65894
# [223]	validation-rmse:6.65886
# [224]	validation-rmse:6.65880
# [225]	validation-rmse:6.65867
# [226]	validation-rmse:6.65859
# [227]	validation-rmse:6.65854
# [228]	validation-rmse:6.65849
# [229]	validation-rmse:6.65846
# [230]	validation-rmse:6.65833
# [231]	validation-rmse:6.65827
# [232]	validation-rmse:6.65820
# [233]	validation-rmse:6.65812
# [234]	validation-rmse:6.65812
# [235]	validation-rmse:6.65805
# [236]	validation-rmse:6.65791
# [237]	validation-rmse:6.65788
# [238]	validation-rmse:6.65785
# [239]	validation-rmse:6.65778
# [240]	validation-rmse:6.65770
# [241]	validation-rmse:6.65760
# [242]	validation-rmse:6.65753
# [243]	validation-rmse:6.65747
# [244]	validation-rmse:6.65740
# [245]	validation-rmse:6.65737
# [246]	validation-rmse:6.65722
# [247]	validation-rmse:6.65718
# [248]	validation-rmse:6.65717
# [249]	validation-rmse:6.65710
# [250]	validation-rmse:6.65703
# [251]	validation-rmse:6.65690
# [252]	validation-rmse:6.65685
# [253]	validation-rmse:6.65681
# [254]	validation-rmse:6.65677
# [255]	validation-rmse:6.65671
# [256]	validation-rmse:6.65669
# [257]	validation-rmse:6.65663
# [258]	validation-rmse:6.65657
# [259]	validation-rmse:6.65649
# [260]	validation-rmse:6.65643
# [261]	validation-rmse:6.65642
# [262]	validation-rmse:6.65638
# [263]	validation-rmse:6.65634
# [264]	validation-rmse:6.65633
# [265]	validation-rmse:6.65630
# [266]	validation-rmse:6.65621
# [267]	validation-rmse:6.65611
# ...
# [242]	validation-rmse:6.65281
# [243]	validation-rmse:6.65281
# [244]	validation-rmse:6.65273
# [245]	validation-rmse:6.65270
# [246]	validation-rmse:6.65258
# [247]	validation-rmse:6.65257
# [248]	validation-rmse:6.65247
# [249]	validation-rmse:6.65244
# [250]	validation-rmse:6.65222
# [251]	validation-rmse:6.65223
# [252]	validation-rmse:6.65222
# [253]	validation-rmse:6.65207
# [254]	validation-rmse:6.65190
# [255]	validation-rmse:6.65198
# [256]	validation-rmse:6.65202
# [257]	validation-rmse:6.65197
# [258]	validation-rmse:6.65186
# [259]	validation-rmse:6.65181
# [260]	validation-rmse:6.65170
# [261]	validation-rmse:6.65171
# [262]	validation-rmse:6.65161
# [263]	validation-rmse:6.65166
# [264]	validation-rmse:6.65142
# [265]	validation-rmse:6.65119
# [266]	validation-rmse:6.65117
# [267]	validation-rmse:6.65122
# [268]	validation-rmse:6.65115
# [269]	validation-rmse:6.65108
# [270]	validation-rmse:6.65101
# [271]	validation-rmse:6.65084
# [272]	validation-rmse:6.65075
# [273]	validation-rmse:6.65067
# [274]	validation-rmse:6.65070
# [275]	validation-rmse:6.65067
# [276]	validation-rmse:6.65067
# [277]	validation-rmse:6.65063
# [278]	validation-rmse:6.65053
# [279]	validation-rmse:6.65046
# [280]	validation-rmse:6.65046
# [281]	validation-rmse:6.65044
# [282]	validation-rmse:6.65036
# [283]	validation-rmse:6.65036
# [284]	validation-rmse:6.65034
# [285]	validation-rmse:6.65042
# [286]	validation-rmse:6.65044
# [287]	validation-rmse:6.65019
# [288]	validation-rmse:6.65023
# [289]	validation-rmse:6.65008
# [290]	validation-rmse:6.65006
# [291]	validation-rmse:6.65008
# [292]	validation-rmse:6.65008
#  12%|████████████▎                                                                                          | 6/50 [19:12<2:20:52, 192.09s/trial, best loss: 6.3250186081862045]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 11
#       1 search_space = {
#       2     'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
#       3     'learning_rate': hp.loguniform('learning_rate', -3, 0),
#    (...)
#       8     'seed': 42
#       9 }
# ---> 11 best_result = fmin(
#      12     fn=objective,
#      13     space=search_space,
#      14     algo=tpe.suggest,
#      15     max_evals=50,
#      16     trials=Trials()
#      17 )
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540     return trials.fmin(
#     541         fn,
#     542         space,
#     543         algo=algo,
#     544         max_evals=max_evals,
#     545         timeout=timeout,
#     546         loss_threshold=loss_threshold,
#     547         max_queue_len=max_queue_len,
#     548         rstate=rstate,
#     549         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     550         verbose=verbose,
#     551         catch_eval_exceptions=catch_eval_exceptions,
#     552         return_argmin=return_argmin,
#     553         show_progressbar=show_progressbar,
#     554         early_stop_fn=early_stop_fn,
#     555         trials_save_file=trials_save_file,
#     556     )
#     558 if trials is None:
#     559     if os.path.exists(trials_save_file):
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo=algo,
#     675     max_evals=max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687     early_stop_fn=early_stop_fn,
#     688     trials_save_file=trials_save_file,
#     689 )
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     297     time.sleep(self.poll_interval_secs)
#     298 else:
#     299     # -- loop over trials and do the jobs directly
# --> 300     self.serial_evaluate()
#     302 self.trials.refresh()
#     303 if self.trials_save_file != "":
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     176 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177 try:
# --> 178     result = self.domain.evaluate(spec, ctrl)
#     179 except Exception as e:
#     180     logger.error("job exception: %s" % str(e))
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     883 else:
#     884     # -- the "work" of evaluating `config` can be written
#     885     #    either into the pyll part (self.expr)
#     886     #    or the normal Python part (self.fn)
#     887     pyll_rval = pyll.rec_eval(
#     888         self.expr,
#     889         memo=memo,
#     890         print_node_on_error=self.rec_eval_print_node_on_error,
#     891     )
# --> 892     rval = self.fn(pyll_rval)
#     894 if isinstance(rval, (float, int, np.number)):
#     895     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# Cell In[30], line 5, in objective(params)
#       3 mlflow.set_tag("model", "xgboost")
#       4 mlflow.log_params(params)
# ----> 5 booster = xgb.train(
#       6     params=params,
#       7     dtrain=train,
#       8     num_boost_round=1000,
#       9     evals=[(valid, 'validation')],
#      10     early_stopping_rounds=50
#      11 )
#      12 y_pred = booster.predict(valid)
#      13 rmse = root_mean_squared_error(y_val, y_pred)
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, iteration=i, fobj=obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:2101, in Booster.update(self, dtrain, iteration, fobj)
#    2097 self._assign_dmatrix_features(dtrain)
#    2099 if fobj is None:
#    2100     _check_call(
# -> 2101         _LIB.XGBoosterUpdateOneIter(
#    2102             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2103         )
#    2104     )
#    2105 else:
#    2106     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:
